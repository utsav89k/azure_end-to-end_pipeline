# %%
user_df = spark.read.format("delta").load("s3://pipeline-project-uk/bronze/Destination/DimUser/data")

# %%
user_df.display()

# %%
# Artist
artist_df = spark.read.format("delta").load("s3://pipeline-project-uk/bronze/Destination/DimArtist/data")

# %%
artist_df.display()

# %%
# Track

track_df = spark.read.format("delta").load("s3://pipeline-project-uk/bronze/Destination/DimTrack/data")

# %%
track_df.display()

# %%
# Date Dimension


date_df = spark.read.format("delta").load("s3://pipeline-project-uk/bronze/Destination/DimDate/data")

# %%
date_df.display()

# %%
# Fact Table 
fact_df = spark.read.format("delta").load("s3://pipeline-project-uk/bronze/Destination/FactData/data")

# %%
display(fact_df)
