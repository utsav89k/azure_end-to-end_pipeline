# %%
df=spark.read.format("parquet").load("s3://pipeline-project-uk/bronze/DimDate")

# %%
display(df)

# %%
df.printSchema()

# %%
df.show()

# %%
from pyspark.sql.functions import *

# %%
df = df.withColumn("month_name",date_format(col("date"), "MMMM")) \
           .withColumn("is_weekend", col("weekday").isin("Saturday", "Sunday")) \
           .withColumn("start_of_quarter",to_date(date_trunc("quarter", col("date"))))

# %%
df.display()
